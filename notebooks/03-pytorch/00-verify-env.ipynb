# %% [markdown]
# # Verify environment of PyTorch installation

# %%
import torch

print(f'Import PyTorch V{torch.__version__}')
# Out:
# Import PyTorch V2.1.1

# %%
shape = (4, 5)
print(f'Create a random tensor in shape {shape}')
x = torch.rand(*shape)
print(x)
# Out:
# Create a random tensor in shape (4, 5)
# tensor([[0.6326, 0.0818, 0.1936, 0.5419, 0.3848],
#         [0.6613, 0.1475, 0.3949, 0.2543, 0.8159],
#         [0.0212, 0.2447, 0.8616, 0.5203, 0.6796],
#         [0.6903, 0.3622, 0.8840, 0.2857, 0.2503]])

# %%
print(f'Avalability of CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'There are {torch.cuda.device_count()} GPU devices')
# Out:
# Avalability of CUDA: True
# There are 1 GPU devices

# %%
import d2l
print(f'Import D2L V{d2l.__version__}')
# Out:
# Import D2L V1.0.3
